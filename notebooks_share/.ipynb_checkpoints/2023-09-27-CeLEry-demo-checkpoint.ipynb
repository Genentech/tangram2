# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Import necessary standard packages

# %%
import tempfile
import subprocess
from pathlib import Path

# %% [markdown]
# Import evaluation module

# %%
EVAL_PTH = '../src/'
import sys
if EVAL_PTH not in sys.path:
    sys.path.append(EVAL_PTH)
import eval as ev

# %% [markdown]
# Specify path to config file

# %%
CONFIG_PTH = '../examples/eval_config/cel_config.yaml'

# %% [markdown]
# Inspect config file

# %%
# !cat $CONFIG_PTH
# Out:
# ---
#
# data:
#   exp1:
#     sp:
#       path: '/gstore/data/resbioai/spacerangers/cci-explore/pipeline/example_data/qx_visified.h5ad'
#     sc:
#       path: '/gstore/data/resbioai/spacerangers/cci-explore/pipeline/example_data/qx_mappable.h5ad'
#
# methods:
#   exp1:
#     - map_CeLEry
#
# method_params:
#   exp1:
#     map_CeLEry:
#       num_epochs_max: 5
#
# preprocess:
#   exp1:
#     exp1:
#       sp:
#         CeLEry_pp:
#       sc:
#         CeLEry_pp:
#
# metrics:
#   exp1:
#     map_CeLEry:
#       map_RMSE: spatial

# %% [markdown]
# Read config file

# %%
import yaml

with open(CONFIG_PTH, 'r') as f:
    design = yaml.safe_load(f)

# %% [markdown]
# Run evaluation and look at output (saved to temporary folder for demo purpose, will be removed once context closes).
# <br>
# <br>
# **Note**: if you actually want to inspect the results, change the context from a `TemporaryDirectory` to any path of your choice.

# %%
with tempfile.TemporaryDirectory() as tmpdir:
    ev.run.run(design,tmpdir)

    subprocess.run(['tree',tmpdir])
    res_files = list(Path(tmpdir).rglob('*.txt'))
    for fn in res_files:
        print('\n Content of: {}'.format(fn))
        subprocess.run(['cat',fn])
# Out:
# 100%|███████████████████████████████████████████████████████████| 1032/1032 [00:02<00:00, 356.84it/s]
# Epoch:1, Loss:70.0458
# 100%|███████████████████████████████████████████████████████████| 1032/1032 [00:02<00:00, 374.91it/s]
# Epoch:2, Loss:57.3067
# 100%|███████████████████████████████████████████████████████████| 1032/1032 [00:02<00:00, 370.83it/s]
# Epoch:3, Loss:51.8754
# 100%|███████████████████████████████████████████████████████████| 1032/1032 [00:02<00:00, 371.98it/s]
# Epoch:4, Loss:47.6720
# 100%|███████████████████████████████████████████████████████████| 1032/1032 [00:02<00:00, 366.29it/s]
# Epoch:5, Loss:44.4852
# Folder already exists
# /local/16194114/tmp4upgh1do
# └── exp1
#     └── map_CeLEry
#         └── map_rmse.txt
#
# 2 directories, 1 file
#
#  Content of: /local/16194114/tmp4upgh1do/exp1/map_CeLEry/map_rmse.txt
# 24568449.877232786
