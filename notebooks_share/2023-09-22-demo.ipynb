# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Import necessary standard packages

# %%
import tempfile
import subprocess

# %% [markdown]
# Import evaluation module

# %%
EVAL_PTH = '../src/'
import sys
if EVAL_PTH not in sys.path:
    sys.path.append(EVAL_PTH)
import eval as ev

# %% [markdown]
# Specify path to config file

# %%
CONFIG_PTH = '../examples/eval_config/config.yaml'

# %% [markdown]
# Inspect config file

# %%
# !cat $CONFIG_PTH
# Out:
# ---
#
# data:
#   exp1:
#     sp:
#       path: '/gstore/data/resbioai/spacerangers/cci-explore/pipeline/example_data/qx_visified.h5ad'
#     sc:
#       path: '/gstore/data/resbioai/spacerangers/cci-explore/pipeline/example_data/qx_mappable.h5ad'
#
# methods:
#   exp1:
#     - map_random
#     - map_tangram_v1
#
# method_params:
#   all:
#     map_tangram_v1:
#       num_epochs: 10
#
# preprocess:
#   exp1:
#     all:
#       sp:
#         standard_scanpy:
#           target_sum: 1e4
#       sc:
#         total_normalize:
#           target_sum: 1e4
# metrics:
#   exp1:
#     map_tangram_v1:
#       map_jaccard: visify_cell_map
#       map_accuracy: visify_cell_map
#     map_random:
#       map_jaccard: visify_cell_map
#       map_accuracy: visify_cell_map

# %% [markdown]
# Read config file

# %%
import yaml

with open(CONFIG_PTH, 'r') as f:
    design = yaml.safe_load(f)

# %% [markdown]
# Run evaluation and look at output (saved to temporary folder for demo purpose)

# %%
from eval.constants import PreProcess

# %%
with tempfile.TemporaryDirectory() as tmpdir:
    ev.run.run(design,tmpdir)

    subprocess.run(['tree',tmpdir])
# Out:
# WARNING: adata.X seems to be already log-transformed.
# INFO:root:313 training genes are saved in `uns``training_genes` of both single cell and spatial Anndatas.
# INFO:root:313 overlapped genes are saved in `uns``overlap_genes` of both single cell and spatial Anndatas.
# INFO:root:uniform based density prior is calculated and saved in `obs``uniform_density` of the spatial Anndata.
# INFO:root:rna count based density prior is calculated and saved in `obs``rna_count_based_density` of the spatial Anndata.
# INFO:root:Allocate tensors for mapping.
# INFO:root:Begin training with 313 genes and rna_count_based density_prior in cells mode...
# INFO:root:Printing scores every 100 epochs.
# Score: 0.656, KL reg: 0.116
# INFO:root:Saving results..
# /local/16194114/tmpgq3rovv1
# └── exp1
#     ├── map_random
#     │   ├── map_accuracy.txt
#     │   └── map_jaccard.txt
#     └── map_tangram_v1
#         ├── map_accuracy.txt
#         └── map_jaccard.txt
#
# 3 directories, 4 files
