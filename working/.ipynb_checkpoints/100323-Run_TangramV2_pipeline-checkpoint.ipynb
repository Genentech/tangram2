# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Import necessary standard packages

# %%
import tempfile
import subprocess
from pathlib import Path

# %% [markdown]
# Import evaluation module

# %%
EVAL_PTH = '../src/'
import sys
if EVAL_PTH not in sys.path:
    sys.path.append(EVAL_PTH)
import eval as ev

# %%
# Listing all the available methods, etc.
ev.info.list_methods()
ev.info.list_metrics()
ev.info.list_pp()
# Out:
# methods:
#   - map_random
#   - map_max_corr
#   - map_tangram_v1
#   - map_tangram_v2
#   - map_CeLEry
#   - prd_tangram_v1
#   - prd_tangram_v2
#   - grp_threshold
#   - dea_scanpy
# metrics:
#   - map_jaccard
#   - map_accuracy
#   - map_rmse
#   - dev_print
# preprocess:
#   - standard_scanpy
#   - normalize_totaly
#   - CeLEry

# %% [markdown]
# Specify path to config file

# %%
CONFIG_PTH = 'hejinwf_config.yaml'

# %% [markdown]
# Inspect config file

# %%
# !cat $CONFIG_PTH
# Out:
# ---
#
# data:
#   exp1:
#     sp:
#       path: '/gstore/data/resbioai/tangram2_data/breast_cancer/spatial/ad_sp_CID44971.h5ad'
#     sc:
#       path: '/gstore/data/resbioai/tangram2_data/breast_cancer/single_cell/Wu_etal_2021_BRCA_scRNASeq/ad_sc.h5ad'
#
# methods:
#   exp1:
#     - wf_hejin
#
# method_params:
#   exp1:
#     wf_hejin:
#       map_args:
#         num_epochs: 1000
#       group_args:
#         feature_name: 'cd274'
#         thres_x: 9
#
#
# preprocess:
#   exp1:
#     sc:
#       total_normalize:
#         target_sum: 1e4
# metrics:
#   exp1:
#     wf_hejin:
#       dev_print:

# %% [markdown]
# Read config file

# %% [markdown]
# we'll use a "stupid" metric that just prints the output, since this is for illustrative purposes.

# %%
import yaml

with open(CONFIG_PTH, 'r') as f:
    design = yaml.safe_load(f)

# %% [markdown]
# Run evaluation and look at output (saved to temporary folder for demo purpose, will be removed once context closes).
# <br>
# <br>
# **Note**: if you actually want to inspect the results, change the context from a `TemporaryDirectory` to any path of your choice.

# %%
with tempfile.TemporaryDirectory() as tmpdir:
    ev.run.run(design,tmpdir)

    subprocess.run(['tree',tmpdir])
    res_files = list(Path(tmpdir).rglob('*.txt'))
    for fn in res_files:
        print('\n Content of: {}'.format(fn))
        subprocess.run(['cat',fn])
# Out:
# INFO:root:16095 training genes are saved in `uns``training_genes` of both single cell and spatial Anndatas.
# INFO:root:16095 overlapped genes are saved in `uns``overlap_genes` of both single cell and spatial Anndatas.
# INFO:root:uniform based density prior is calculated and saved in `obs``uniform_density` of the spatial Anndata.
# INFO:root:rna count based density prior is calculated and saved in `obs``rna_count_based_density` of the spatial Anndata.
# INFO:root:Allocate tensors for mapping.
# INFO:root:Begin training with 16095 genes and rna_count_based density_prior in cells mode...
# INFO:root:Printing scores every 100 epochs.
# Score: 0.768, VG reg: 0.768, KL reg: 0.255
# Score: 0.786, VG reg: 0.786, KL reg: 0.001
# Score: 0.793, VG reg: 0.793, KL reg: 0.000
# Score: 0.796, VG reg: 0.796, KL reg: 0.000
# Score: 0.798, VG reg: 0.798, KL reg: 0.000
# Score: 0.799, VG reg: 0.799, KL reg: 0.000
# Score: 0.800, VG reg: 0.800, KL reg: 0.000
# Score: 0.800, VG reg: 0.800, KL reg: 0.000
# Score: 0.801, VG reg: 0.801, KL reg: 0.000
# Score: 0.801, VG reg: 0.801, KL reg: 0.000
# INFO:root:Saving results..
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 with tempfile.TemporaryDirectory() as tmpdir:
# ----> 2     ev.run.run(design,tmpdir)
#       4     subprocess.run(['tree',tmpdir])
#       5     res_files = list(Path(tmpdir).rglob('*.txt'))
#
# File ~/notebooks/cci/pipeline/working/../src/eval/run.py:63, in run(config, root_dir)
#      57 inp_kwargs = dict(
#      58     to_spatial_key=data[exp]["sp"].get("spatial_key", "spatial"),
#      59     from_spatial_key=data[exp]["sc"].get("spatial_key", None),
#      60 )
#      61 met_input = met_kwargs | inp_kwargs | method_params[exp].get(met_name, {})
# ---> 63 met_val = method.run(input_dict, **met_input)
#      65 method_metrics = ut.recursive_get(metrics, exp, met_name)
#      67 for metric_name, metric_props in method_metrics.items():
#
# File ~/notebooks/cci/pipeline/working/../src/eval/workflows.py:85, in WorkFlowClass.run(cls, input_dict, map_args, pred_args, group_args, dea_args, **kwargs)
#      75 @classmethod
#      76 def run(
#      77     cls,
#    (...)
#      83     **kwargs,
#      84 ):
# ---> 85     out = cls.flow.run(
#      86         input_dict=input_dict,
#      87         map_args=map_args,
#      88         pred_args=pred_args,
#      89         group_args=group_args,
#      90         dea_args=dea_args,
#      91         **kwargs,
#      92     )
#      93     return out
#
# File ~/notebooks/cci/pipeline/working/../src/eval/workflows.py:58, in Composite.run(self, input_dict, map_args, pred_args, group_args, dea_args, **kwargs)
#      49 def run(
#      50     self,
#      51     input_dict: Dict[str, Any],
#    (...)
#      56     **kwargs,
#      57 ):
# ---> 58     out = self.map.run(input_dict, **map_args)
#      59     input_dict.update(out)
#      60     out = self.pred.run(input_dict, **pred_args)
#
# File ~/notebooks/cci/pipeline/working/../src/eval/map_methods.py:226, in TangramMap.run(cls, input_dict, train_genes, to_spatial_key, from_spatial_key, return_sparse, pos_by_argmax, pos_by_weight, num_epochs, hard_map, **kwargs)
#     223 col_idx = np.arange(n_cols)
#     225 if pos_by_argmax:
# --> 226     kd = cKDTree(S_to)
#     227     _, idxs = kd.query(S_from, k=2)
#     229     row_idx = idxs[:, 1::].flatten()
#
# File _ckdtree.pyx:561, in scipy.spatial._ckdtree.cKDTree.__init__()
#
# ValueError: data must be finite, check for nan or inf values
